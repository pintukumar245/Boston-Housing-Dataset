# %%
import pandas as pd

# %%
dataset=pd.read_csv(r"C:\Users\pintu\OneDrive\Desktop\machine lerinig all dataset\liniear.csv")

# %%
dataset.head(3)
# Out:
#    Unnamed: 0     crim    zn  indus  chas    nox     rm   age     dis  rad  \
# 0           1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1
# 1           2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2
# 2           3  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2
#
#    tax  ptratio   black  lstat  medv
# 0  296     15.3  396.90   4.98  24.0
# 1  242     17.8  396.90   9.14  21.6
# 2  242     17.8  392.83   4.03  34.7

# %%
dataset.drop("Unnamed: 0",axis=1,inplace=True)

# %%
dataset.head(3)
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
#
#     black  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7

# %%
x=dataset.iloc[:,:-1]
y=dataset["medv"]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=30)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr.predict([[0.00632,18.0,2.31,0,0.538,6.575,65.2,4.0900,1,296,15.3,396.90,4.98]])
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([30.09870192])

# %%
lr.score(x_test,y_test)*100
# Out:
# 71.81173900062076

# %%
lr.score(x_train,y_train)*100
# Out:
# 74.30248871225487

# %%
house_prd=lr.predict(x_test)

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(y_test,house_prd)
# Out:
# 17.933042188699194

# %%
dataset["medv_predict"]=lr.predict(x)

# %%
dataset.head(4)
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
#
#     black  lstat  medv  medv_predict
# 0  396.90   4.98  24.0     30.098702
# 1  396.90   9.14  21.6     25.162399
# 2  392.83   4.03  34.7     30.758705
# 3  394.63   2.94  33.4     28.751032
